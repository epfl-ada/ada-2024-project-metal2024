# %%
import pickle

# %%
results = pickle.load(open("ngram_results.pkl", "rb"))

# %%
type(results)
# Out:
# list

# %%
zip1 = results[4][1]
for e in zip1:
    print(e)
# Out:
# ('seventh-day', 'adventist', 'church')
# ('adventist', 'church', 'pastor')
# ('church', 'pastor', 'michael')
# ('pastor', 'michael', 'chamberlain,')
# ('michael', 'chamberlain,', 'his')
# ('chamberlain,', 'his', 'wife')
# ('his', 'wife', 'lindy,')
# ('wife', 'lindy,', 'their')
# ('lindy,', 'their', 'two')
# ('their', 'two', 'sons,')
# ('two', 'sons,', 'and')
# ('sons,', 'and', 'their')
# ('and', 'their', 'nine-week-old')
# ('their', 'nine-week-old', 'daughter')
# ('nine-week-old', 'daughter', 'azaria')
# ('daughter', 'azaria', 'are')
# ('azaria', 'are', 'on')
# ('are', 'on', 'a')
# ('on', 'a', 'camping')
# ('a', 'camping', 'holiday')
# ('camping', 'holiday', 'in')
# ('holiday', 'in', 'the')
# ('in', 'the', 'outback.')
# ('the', 'outback.', 'with')
# ('outback.', 'with', 'the')
# ('with', 'the', 'baby')
# ('the', 'baby', 'sleeping')
# ('baby', 'sleeping', 'in')
# ('sleeping', 'in', 'their')
# ('in', 'their', 'tent,')
# ('their', 'tent,', 'the')
# ('tent,', 'the', 'family')
# ('the', 'family', 'is')
# ('family', 'is', 'enjoying')
# ('is', 'enjoying', 'a')
# ('enjoying', 'a', 'barbecue')
# ('a', 'barbecue', 'with')
# ('barbecue', 'with', 'their')
# ('with', 'their', 'fellow')
# ('their', 'fellow', 'campers')
# ('fellow', 'campers', 'when')
# ('campers', 'when', 'a')
# ('when', 'a', 'cry')
# ('a', 'cry', 'is')
# ('cry', 'is', 'heard.')
# ('is', 'heard.', 'lindy')
# ('heard.', 'lindy', 'returns')
# ('lindy', 'returns', 'to')
# ('returns', 'to', 'the')
# ('to', 'the', 'tent')
# ('the', 'tent', 'to')
# ('tent', 'to', 'check')
# ('to', 'check', 'on')
# ('check', 'on', 'azaria')
# ('on', 'azaria', 'and')
# ('azaria', 'and', 'is')
# ('and', 'is', 'certain')
# ('is', 'certain', 'she')
# ('certain', 'she', 'sees')
# ('she', 'sees', 'a')
# ('sees', 'a', 'dingo')
# ('a', 'dingo', 'with')
# ('dingo', 'with', 'something')
# ('with', 'something', 'in')
# ('something', 'in', 'its')
# ('in', 'its', 'mouth')
# ('its', 'mouth', 'running')
# ('mouth', 'running', 'off')
# ('running', 'off', 'as')
# ('off', 'as', 'she')
# ('as', 'she', 'approaches.')
# ('she', 'approaches.', 'when')
# ('approaches.', 'when', 'she')
# ('when', 'she', 'discovers')
# ('she', 'discovers', 'the')
# ('discovers', 'the', 'infant')
# ('the', 'infant', 'is')
# ('infant', 'is', 'missing,')
# ('is', 'missing,', 'everyone')
# ('missing,', 'everyone', 'joins')
# ('everyone', 'joins', 'forces')
# ('joins', 'forces', 'to')
# ('forces', 'to', 'search')
# ('to', 'search', 'for')
# ('search', 'for', 'her,')
# ('for', 'her,', 'without')
# ('her,', 'without', 'success.')
# ('without', 'success.', 'it')
# ('success.', 'it', 'is')
# ('it', 'is', 'assumed')
# ('is', 'assumed', 'what')
# ('assumed', 'what', 'lindy')
# ('what', 'lindy', 'saw')
# ('lindy', 'saw', 'was')
# ('saw', 'was', 'the')
# ('was', 'the', 'animal')
# ('the', 'animal', 'carrying')
# ('animal', 'carrying', 'off')
# ('carrying', 'off', 'the')
# ('off', 'the', 'child,')
# ('the', 'child,', 'and')
# ('child,', 'and', 'a')
# ('and', 'a', 'subsequent')
# ('a', 'subsequent', 'inquest')
# ('subsequent', 'inquest', 'rules')
# ('inquest', 'rules', 'her')
# ('rules', 'her', 'account')
# ('her', 'account', 'of')
# ('account', 'of', 'events')
# ('of', 'events', 'is')
# ('events', 'is', 'true.')
# ('is', 'true.', 'the')
# ('true.', 'the', 'tide')
# ('the', 'tide', 'of')
# ('tide', 'of', 'public')
# ('of', 'public', 'opinion')
# ('public', 'opinion', 'soon')
# ('opinion', 'soon', 'turns')
# ('soon', 'turns', 'against')
# ('turns', 'against', 'the')
# ('against', 'the', 'chamberlains.')
# ('the', 'chamberlains.', 'for')
# ('chamberlains.', 'for', 'many,')
# ('for', 'many,', 'lindy')
# ('many,', 'lindy', 'seems')
# ('lindy', 'seems', 'too')
# ('seems', 'too', 'stoic,')
# ('too', 'stoic,', 'too')
# ('stoic,', 'too', 'cold-hearted,')
# ('too', 'cold-hearted,', 'and')
# ('cold-hearted,', 'and', 'too')
# ('and', 'too', 'accepting')
# ('too', 'accepting', 'of')
# ('accepting', 'of', 'the')
# ('of', 'the', 'disaster')
# ('the', 'disaster', 'that')
# ('disaster', 'that', 'has')
# ('that', 'has', 'befallen')
# ('has', 'befallen', 'her.')
# ('befallen', 'her.', 'gossip')
# ('her.', 'gossip', 'about')
# ('gossip', 'about', 'her')
# ('about', 'her', 'begins')
# ('her', 'begins', 'to')
# ('begins', 'to', 'swell')
# ('to', 'swell', 'and')
# ('swell', 'and', 'soon')
# ('and', 'soon', 'is')
# ('soon', 'is', 'accepted')
# ('is', 'accepted', 'as')
# ('accepted', 'as', 'statements')
# ('as', 'statements', 'of')
# ('statements', 'of', 'fact.')
# ('of', 'fact.', 'the')
# ('fact.', 'the', "couple's")
# ('the', "couple's", 'beliefs')
# ("couple's", 'beliefs', 'are')
# ('beliefs', 'are', 'not')
# ('are', 'not', 'widely')
# ('not', 'widely', 'practised')
# ('widely', 'practised', 'in')
# ('practised', 'in', 'the')
# ('in', 'the', 'country,')
# ('the', 'country,', 'and')
# ('country,', 'and', 'when')
# ('and', 'when', 'the')
# ('when', 'the', 'media')
# ('the', 'media', 'report')
# ('media', 'report', 'a')
# ('report', 'a', 'rumour')
# ('a', 'rumour', 'that')
# ('rumour', 'that', 'the')
# ('that', 'the', 'name')
# ('the', 'name', 'azaria')
# ('name', 'azaria', 'means')
# ('azaria', 'means', '"sacrifice')
# ('means', '"sacrifice', 'in')
# ('"sacrifice', 'in', 'the')
# ('in', 'the', 'wilderness"')
# ('the', 'wilderness"', ',')
# ('wilderness"', ',', 'the')
# (',', 'the', 'public')
# ('the', 'public', 'is')
# ('public', 'is', 'quick')
# ('is', 'quick', 'to')
# ('quick', 'to', 'believe')
# ('to', 'believe', 'they')
# ('believe', 'they', 'decapitated')
# ('they', 'decapitated', 'their')
# ('decapitated', 'their', 'baby')
# ('their', 'baby', 'with')
# ('baby', 'with', 'a')
# ('with', 'a', 'pair')
# ('a', 'pair', 'of')
# ('pair', 'of', 'scissors')
# ('of', 'scissors', 'as')
# ('scissors', 'as', 'part')
# ('as', 'part', 'of')
# ('part', 'of', 'a')
# ('of', 'a', 'bizarre')
# ('a', 'bizarre', 'religious')
# ('bizarre', 'religious', 'rite.')
# ('religious', 'rite.', 'law-enforcement')
# ('rite.', 'law-enforcement', 'officials')
# ('law-enforcement', 'officials', 'find')
# ('officials', 'find', 'new')
# ('find', 'new', 'witnesses,')
# ('new', 'witnesses,', 'forensics')
# ('witnesses,', 'forensics', 'experts,')
# ('forensics', 'experts,', 'and')
# ('experts,', 'and', 'a')
# ('and', 'a', 'lot')
# ('a', 'lot', 'of')
# ('lot', 'of', 'circumstantial')
# ('of', 'circumstantial', 'evidence—including')
# ('circumstantial', 'evidence—including', 'a')
# ('evidence—including', 'a', 'small')
# ('a', 'small', 'wooden')
# ('small', 'wooden', 'coffin')
# ('wooden', 'coffin', 'michael')
# ('coffin', 'michael', 'uses')
# ('michael', 'uses', 'as')
# ('uses', 'as', 'a')
# ('as', 'a', 'receptacle')
# ('a', 'receptacle', 'for')
# ('receptacle', 'for', 'his')
# ('for', 'his', "parishioners'")
# ('his', "parishioners'", 'packs')
# ("parishioners'", 'packs', 'of')
# ('packs', 'of', 'un-smoked')
# ('of', 'un-smoked', 'cigarettes—and')
# ('un-smoked', 'cigarettes—and', 'reopen')
# ('cigarettes—and', 'reopen', 'the')
# ('reopen', 'the', 'investigation,')
# ('the', 'investigation,', 'and')
# ('investigation,', 'and', 'eventually')
# ('and', 'eventually', 'lindy')
# ('eventually', 'lindy', 'is')
# ('lindy', 'is', 'charged')
# ('is', 'charged', 'with')
# ('charged', 'with', 'murder.')
# ('with', 'murder.', 'seven')
# ('murder.', 'seven', 'months')
# ('seven', 'months', 'pregnant,')
# ('months', 'pregnant,', 'she')
# ('pregnant,', 'she', 'ignores')
# ('she', 'ignores', 'her')
# ('ignores', 'her', "attorneys'")
# ('her', "attorneys'", 'advice')
# ("attorneys'", 'advice', 'to')
# ('advice', 'to', 'play')
# ('to', 'play', 'on')
# ('play', 'on', 'the')
# ('on', 'the', "jury's")
# ('the', "jury's", 'sympathy')
# ("jury's", 'sympathy', 'and')
# ('sympathy', 'and', 'appears')
# ('and', 'appears', 'emotionless')
# ('appears', 'emotionless', 'on')
# ('emotionless', 'on', 'the')
# ('on', 'the', 'stand,')
# ('the', 'stand,', 'convincing')
# ('stand,', 'convincing', 'onlookers')
# ('convincing', 'onlookers', 'she')
# ('onlookers', 'she', 'is')
# ('she', 'is', 'guilty')
# ('is', 'guilty', 'of')
# ('guilty', 'of', 'the')
# ('of', 'the', 'crime')
# ('the', 'crime', 'of')
# ('crime', 'of', 'which')
# ('of', 'which', 'she')
# ('which', 'she', 'is')
# ('she', 'is', 'accused.')
# ('is', 'accused.', 'as')
# ('accused.', 'as', 'the')
# ('as', 'the', 'trial')
# ('the', 'trial', 'progresses,')
# ('trial', 'progresses,', "michael's")
# ('progresses,', "michael's", 'faith')
# ("michael's", 'faith', 'in')
# ('faith', 'in', 'his')
# ('in', 'his', 'religion')
# ('his', 'religion', 'and')
# ('religion', 'and', 'his')
# ('and', 'his', 'belief')
# ('his', 'belief', 'in')
# ('belief', 'in', 'his')
# ('in', 'his', 'wife')
# ('his', 'wife', 'disintegrate,')
# ('wife', 'disintegrate,', 'and')
# ('disintegrate,', 'and', 'he')
# ('and', 'he', 'stumbles')
# ('he', 'stumbles', 'through')
# ('stumbles', 'through', 'his')
# ('through', 'his', 'testimony,')
# ('his', 'testimony,', 'suggesting')
# ('testimony,', 'suggesting', 'he')
# ('suggesting', 'he', 'is')
# ('he', 'is', 'concealing')
# ('is', 'concealing', 'the')
# ('concealing', 'the', 'truth.')
# ('the', 'truth.', 'in')
# ('truth.', 'in', 'october')
# ('in', 'october', '1982,')
# ('october', '1982,', 'lindy')
# ('1982,', 'lindy', 'is')
# ('lindy', 'is', 'found')
# ('is', 'found', 'guilty')
# ('found', 'guilty', 'and')
# ('guilty', 'and', 'sentenced')
# ('and', 'sentenced', 'to')
# ('sentenced', 'to', 'life')
# ('to', 'life', 'imprisonment')
# ('life', 'imprisonment', 'with')
# ('imprisonment', 'with', 'hard')
# ('with', 'hard', 'labour,')
# ('hard', 'labour,', 'while')
# ('labour,', 'while', 'michael')
# ('while', 'michael', 'is')
# ('michael', 'is', 'found')
# ('is', 'found', 'guilty')
# ('found', 'guilty', 'as')
# ('guilty', 'as', 'an')
# ('as', 'an', 'accessory')
# ('an', 'accessory', 'and')
# ('accessory', 'and', 'given')
# ('and', 'given', 'an')
# ('given', 'an', '18-month')
# ('an', '18-month', 'suspended')
# ('18-month', 'suspended', 'sentence.')
# ('suspended', 'sentence.', 'more')
# ('sentence.', 'more', 'than')
# ('more', 'than', 'three')
# ('than', 'three', 'years')
# ('three', 'years', 'later,')
# ('years', 'later,', 'while')
# ('later,', 'while', 'searching')
# ('while', 'searching', 'for')
# ('searching', 'for', 'the')
# ('for', 'the', 'body')
# ('the', 'body', 'of')
# ('body', 'of', 'an')
# ('of', 'an', 'english')
# ('an', 'english', 'tourist')
# ('english', 'tourist', 'who')
# ('tourist', 'who', 'fell')
# ('who', 'fell', 'from')
# ('fell', 'from', 'uluru,')
# ('from', 'uluru,', 'police')
# ('uluru,', 'police', 'discover')
# ('police', 'discover', 'a')
# ('discover', 'a', 'small')
# ('a', 'small', 'item')
# ('small', 'item', 'of')
# ('item', 'of', 'clothing')
# ('of', 'clothing', 'that')
# ('clothing', 'that', 'is')
# ('that', 'is', 'identified')
# ('is', 'identified', 'as')
# ('identified', 'as', 'the')
# ('as', 'the', 'jacket')
# ('the', 'jacket', 'lindy')
# ('jacket', 'lindy', 'had')
# ('lindy', 'had', 'insisted')
# ('had', 'insisted', 'azaria')
# ('insisted', 'azaria', 'was')
# ('azaria', 'was', 'wearing')
# ('was', 'wearing', 'over')
# ('wearing', 'over', 'her')
# ('over', 'her', 'jumpsuit,')
# ('her', 'jumpsuit,', 'which')
# ('jumpsuit,', 'which', 'had')
# ('which', 'had', 'been')
# ('had', 'been', 'recovered')
# ('been', 'recovered', 'early')
# ('recovered', 'early', 'in')
# ('early', 'in', 'the')
# ('in', 'the', 'investigation.')
# ('the', 'investigation.', 'she')
# ('investigation.', 'she', 'is')
# ('she', 'is', 'immediately')
# ('is', 'immediately', 'released')
# ('immediately', 'released', 'from')
# ('released', 'from', 'prison,')
# ('from', 'prison,', 'the')
# ('prison,', 'the', 'case')
# ('the', 'case', 'reopened')
# ('case', 'reopened', 'and')
# ('reopened', 'and', 'all')
# ('and', 'all', 'convictions')
# ('all', 'convictions', 'against')
# ('convictions', 'against', 'the')
# ('against', 'the', 'chamberlains')
# ('the', 'chamberlains', 'overturned.')

# %%
from collections import Counter

zip1 = results[6][1]

all_items = [e for e in zip1]

count = Counter(all_items)

# %%
res = list(count.items())#.sort(key= lambda x: x[1])

# %%
for words, count in res:
    if count > 1:
        print(words, count)
# Out:
# ('to', 'his', 'apartment') 2
# ('his', 'apartment', 'in') 2
# ('apartment', 'in', 'jersey') 2
# ('to', 'the', 'roof') 2
# ('where', 'she', 'finds') 2
# ('she', 'finds', 'a') 2
# ('hello', 'kitty', 'backpack') 2
# ('dahlia', 'agrees', 'to') 2
# ('agrees', 'to', 'move') 2
# ('who', 'appears', 'to') 2
# ('takes', 'her', 'to') 2
# ('her', 'to', 'his') 2
# ('the', 'water', 'tank,') 2
# ('was', 'with', 'her') 2
# ('the', 'girl', 'was') 2
# ('in', 'the', 'elevator,') 2
