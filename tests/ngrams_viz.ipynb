# %%
import pickle
N = 1

# %%
results = pickle.load(open(f"results/{N}gram_results.pkl", "rb"))

# %%
type(results)
# Out:
# list

# %%
zip1 = results[14][1]
for e in zip1:
    print(e)
# Out:
# ('following',)
# ('sudden',)
# ('death',)
# ('father',)
# ('local',)
# ('church',)
# ('donated',)
# ('scholarship',)
# ('fund',)
# ('kid',)
# ('so',)
# ('can',)
# ('go',)
# ('play',)
# ('now',)
# ('drives',)
# ('sports',)
# ('car',)
# ('called',)
# ('manager',)
# ('record',)
# ('attracts',)
# ('attention',)
# ('music',)
# ('producer',)
# ('shelia',)
# ('landreaux',)
# ('whose',)
# ('talent',)
# ('scout',)
# ('rick',)
# ('spotted',)
# ('kid',)
# ('play',)
# ('performing',)
# ('community',)
# ('shelia',)
# ('willing',)
# ('help',)
# ('finance',)
# ('kid',)
# ('demo',)
# ('session',)
# ('if',)
# ('can',)
# ('commit',)
# ('taking',)
# ('act',)
# ('top',)
# ('kid',)
# ('however',)
# ('immediately',)
# ('backs',)
# ('out',)
# ('because',)
# ('commit',)
# ('act',)
# ('go',)
# ('causing',)
# ('rift',)
# ('between',)
# ('two',)
# ('kid',)
# ('sydney',)
# ('both',)
# ('move',)
# ('into',)
# ('new',)
# ('student',)
# ('accommodations',)
# ('room',)
# ('mate',)
# ('white',)
# ('rapper',)
# ...

# %%
from collections import Counter

zip1 = results[21][1]

all_items = [e for e in zip1]

count = Counter(all_items)

# %%
res = list(count.items())#.sort(key= lambda x: x[1])

# %%
for words, count in res:
    #print(words, count)
    if count > 1:
        print(words, count)
# Out:
# ('shop',) 2
# ('corner',) 2
# ('red',) 7
# ('as',) 3
# ('sound',) 3
# ('turns',) 2
# ('into',) 3
# ('clown',) 3
# ('juggling',) 4
# ('receives',) 2
# ('only',) 3
# ('lumpy',) 5
# ('three',) 2
# ('balls',) 4
# ('riding',) 2
# ('them',) 2
# ('back',) 2
# ('this',) 2
# ('before',) 2
# ('ball',) 2
# ('while',) 2
# ('other',) 2
# ('two',) 2
# ('then',) 2

# %%
    """
('hello', 'kitty', 'backpack') 2
('dahlia', 'agrees', 'move') 2
('kyle', 'picks', 'up') 2
    """

    """
    ('apartment', 'jersey') 2
('dahlia', 'cecilia') 2
('hello', 'kitty') 2
('kitty', 'backpack') 2
('dahlia', 'agrees') 2
('agrees', 'move') 2
('dark', 'water') 2
('kyle', 'picks') 2
('picks', 'up') 2
    """
# Out:
# "\n('apartment', 'jersey') 2\n('dahlia', 'cecilia') 2\n('hello', 'kitty') 2\n('kitty', 'backpack') 2\n('dahlia', 'agrees') 2\n('agrees', 'move') 2\n('dark', 'water') 2\n('kyle', 'picks') 2\n('picks', 'up') 2\n"

# %%
    """
    ('psychic', 'research') 2
    """
# Out:
# "\n('psychic', 'research') 2\n"

# %%
dict(res)
# Out:
# {('set',): 1,
#  ('lonely',): 1,
#  ('city',): 1,
#  ('rainy',): 1,
#  ('film',): 1,
#  ('takes',): 1,
#  ('place',): 1,
#  ('bicycle',): 1,
#  ('shop',): 2,
#  ('closed',): 1,
#  ('corner',): 2,
#  ('sleeps',): 1,
#  ('red',): 7,
#  ('unicycle',): 1,
#  ('languishes',): 1,
#  ('waiting',): 1,
#  ('as',): 3,
#  ('camera',): 1,
#  ('zooms',): 1,
#  ('sound',): 3,
#  ('rain',): 1,
#  ('falling',): 1,
#  ('turns',): 2,
#  ('into',): 3,
#  ('go',): 1,
#  ('being',): 1,
#  ('ridden',): 1,
#  ('circus',): 1,
#  ('clown',): 3,
#  ('part',): 1,
#  ('juggling',): 4,
#  ('enters',): 1,
#  ('accompanied',): 1,
#  ('expecting',): 1,
#  ('huge',): 1,
#  ('instead',): 1,
#  ('receives',): 2,
#  ('only',): 3,
#  ('few',): 1,
#  ('scattered',): 1,
#  ('claps',): 1,
#  ('different',): 1,
#  ('parts',): 1,
#  ('lumpy',): 5,
#  ('starts',): 1,
#  ('three',): 2,
#  ('balls',): 4,
#  ('whilst',): 1,
#  ('riding',): 2,
#  ('occasionally',): 1,
#  ('dropping',): 1,
#  ('them',): 2,
#  ('slides',): 1,
# ...

# %%
from collections import Counter
c = Counter()

# %%
c.update(res)

# %%
c
# Out:
# Counter({(('set',), 1): 2,
#          (('lonely',), 1): 2,
#          (('city',), 1): 2,
#          (('rainy',), 1): 2,
#          (('film',), 1): 2,
#          (('takes',), 1): 2,
#          (('place',), 1): 2,
#          (('bicycle',), 1): 2,
#          (('shop',), 2): 2,
#          (('closed',), 1): 2,
#          (('corner',), 2): 2,
#          (('sleeps',), 1): 2,
#          (('red',), 7): 2,
#          (('unicycle',), 1): 2,
#          (('languishes',), 1): 2,
#          (('waiting',), 1): 2,
#          (('as',), 3): 2,
#          (('camera',), 1): 2,
#          (('zooms',), 1): 2,
#          (('sound',), 3): 2,
#          (('rain',), 1): 2,
#          (('falling',), 1): 2,
#          (('turns',), 2): 2,
#          (('into',), 3): 2,
#          (('go',), 1): 2,
#          (('being',), 1): 2,
#          (('ridden',), 1): 2,
#          (('circus',), 1): 2,
#          (('clown',), 3): 2,
#          (('part',), 1): 2,
#          (('juggling',), 4): 2,
# ...

# %%
zip2 = results[25][1]

# %%
zip2

# %%
dict_ = dict(results)

# %%
dict_["1082508"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 dict_["1082508"]
#
# KeyError: '1082508'

# %%
dict_.keys()
# Out:
# dict_keys([23890098, 31186339, 20663735, 2231378, 595909, 5272176, 1952976, 24225279, 2462689, 20532852, 15401493, 18188932, 2940516, 1335380, 1480747, 24448645, 15072401, 4018288, 4596602, 15224586, 15585766, 1760737, 29062594, 29326153, 9252321, 8388648, 10644072, 13455076, 33269085, 2254491, 447194, 24165951, 18549958, 12978934, 8471210, 1925869, 10799612, 3150865, 20591333, 28238240, 5414895, 17124781, 5425205, 28207941, 14330027, 4356664, 19174305, 33417831, 2408359, 1838882, 25755313, 10016997, 8153846, 24486071, 4466226, 27975390, 6167400, 17711304, 18392317, 15161056, 21500407, 3459677, 34420857, 18369853, 529276, 20631892, 24577134, 32556450, 455089, 23266463, 35779717, 23299845, 226664, 25113407, 27403920, 2524925, 657446, 1591973, 12383757, 4355919, 32163620, 11685571, 4039635, 17371197, 1282593, 7504323, 7675415, 3109393, 7580720, 457561, 32137084, 4072739, 8034072, 3470969, 4016437, 17060199, 7481126, 9031450, 1520023, 14582951, 4803289, 1788654, 25388139, 21735071, 1591
# ...
